# %%
# !pip install split_folders
import splitfolders
# Out:
# ...
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\tácio\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\tácio\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\tácio\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\tácio\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\tácio\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\tácio\appdata\local\programs\python\python39\lib\site-packages)

# %%
input_folder = "train_images_v1"
output = "images_splitted_aug_v3"
splitfolders.ratio(input_folder, output, seed=42, ratio=(.7, .2, .1) )
# Out:
# Copying files: 11805 files [00:16, 714.25 files/s]
